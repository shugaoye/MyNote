# %%
import pandas as pd
import yfinance as yf
import myshare_util as msu
import myshare_dividends as msd
from datetime import datetime

msft = yf.Ticker("MSFT")

# %%
msft.financials
# Out:
#                                         6/30/2018 6/30/2017 6/30/2016  \
#
# Total Revenue                           110360000  96571000  91154000
# Cost of Revenue                          38353000  33850000  32780000
# Gross Profit                             72007000  62721000  58374000
# Operating Expenses                              -         -         -
# Research Development                     14726000  12292000  11988000
# Selling General and Administrative       22223000  18807000  19198000
# Non Recurring                                 NaN       NaN       NaN
# Others                                        NaN       NaN       NaN
# Total Operating Expenses                 75302000  64949000  63966000
# Operating Income or Loss                 35058000  31622000  27188000
# Income from Continuing Operations               -         -         -
# Total Other Income/Expenses Net           1416000  -1721000  -1549000
# ...

# %%
msft.balance_sheet
# Out:
#                                       6/30/2018  6/30/2017  6/30/2016  \
#
# Current Assets                                -          -          -
# Cash And Cash Equivalents              11946000    7663000    6510000
# Short Term Investments                121723000  125238000  106531000
# Net Receivables                        26481000   22431000   18277000
# Inventory                               2662000    2181000    2251000
# Other Current Assets                    6850000    5183000    6091000
# Total Current Assets                  169662000  162696000  139660000
# Long Term Investments                   1862000    6023000   10438000
# Property Plant and Equipment           36146000   30289000   18356000
# Goodwill                               35683000   35122000   17872000
# Intangible Assets                       8053000   10106000    3733000
# Accumulated Amortization                    NaN        NaN        NaN
# ...

# %%
msft.cashflow
# Out:
#                                                     6/30/2018  6/30/2017  \
#
# Net Income                                           16571000   25489000
# Operating Activities, Cash Flows Provided By or...          -          -
# Depreciation                                          9900000    7800000
# Adjustments To Net Income                            -3108000    1287000
# Changes In Accounts Receivables                      -3862000   -1216000
# Changes In Liabilities                                7070000    3901000
# Changes In Inventories                                -465000      50000
# Changes In Other Operating Activities                 -459000     349000
# Total Cash Flow From Operating Activities            43884000   39507000
# Investing Activities, Cash Flows Provided By or...          -          -
# Capital Expenditures                                -11632000   -8129000
# Investments                                           6557000  -12511000
# ...
